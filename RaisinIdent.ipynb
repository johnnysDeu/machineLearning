# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnysDeu/machineLearning/blob/main/RaisinIdent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import sklearn

# %%
url='https://raw.githubusercontent.com/johnnysDeu/machineLearning/main/Raisin_Dataset.csv' 
data = pd.read_csv(url)

# %%
data
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# ...

# %%
result=pd.get_dummies(data['Class'],drop_first=True) #sex column is converted to binary 
result
# Out:
#      Kecimen
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 895        0
# 896        0
# 897        0
# 898        0
# 899        0
#
# [900 rows x 1 columns]

# %%
print(list(data.columns))
# Out:
# ['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea', 'Extent', 'Perimeter', 'Class']

# %%
y=result
y
# Out:
#      Kecimen
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 895        0
# 896        0
# 897        0
# 898        0
# 899        0
#
# [900 rows x 1 columns]

# %%
cols=[ 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea', 'Extent', 'Perimeter']

# %%
data=data[cols]
data
# Out:
#      MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# 0         442.246011       253.291155      0.819738       90546  0.758651
# 1         406.690687       243.032436      0.801805       78789  0.684130
# 2         442.267048       266.328318      0.798354       93717  0.637613
# 3         286.540559       208.760042      0.684989       47336  0.699599
# 4         352.190770       290.827533      0.564011       81463  0.792772
# ..               ...              ...           ...         ...       ...
# 895       430.077308       247.838695      0.817263       85839  0.668793
# 896       440.735698       259.293149      0.808629       90899  0.636476
# 897       431.706981       298.837323      0.721684      106264  0.741099
# 898       476.344094       254.176054      0.845739       97653  0.658798
# 899       512.081774       215.271976      0.907345       89197  0.632020
#
#      Perimeter
# 0     1184.040
# 1     1121.786
# 2     1208.575
# ...

# %%
X=data

# %%
Xnew=X.to_numpy()
ynew=y.to_numpy()

# %%
X
# Out:
#      MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# 0         442.246011       253.291155      0.819738       90546  0.758651
# 1         406.690687       243.032436      0.801805       78789  0.684130
# 2         442.267048       266.328318      0.798354       93717  0.637613
# 3         286.540559       208.760042      0.684989       47336  0.699599
# 4         352.190770       290.827533      0.564011       81463  0.792772
# ..               ...              ...           ...         ...       ...
# 895       430.077308       247.838695      0.817263       85839  0.668793
# 896       440.735698       259.293149      0.808629       90899  0.636476
# 897       431.706981       298.837323      0.721684      106264  0.741099
# 898       476.344094       254.176054      0.845739       97653  0.658798
# 899       512.081774       215.271976      0.907345       89197  0.632020
#
#      Perimeter
# 0     1184.040
# 1     1121.786
# 2     1208.575
# ...

# %%
y
# Out:
#      Kecimen
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 895        0
# 896        0
# 897        0
# 898        0
# 899        0
#
# [900 rows x 1 columns]

# %%
perm = np.random.permutation(y.size)
#PRC = 0.7
#plit_point = int(np.ceil(y.shape [0]* PRC))
X_test = Xnew[perm [:180].ravel(),:]
y_test = ynew[perm [:180].ravel()]
X_train = Xnew[perm [180:].ravel(),:]
y_train = ynew[perm [180:].ravel()]

# %%
perm
# Out:
# array([426, 885, 186, 514, 842, 716, 365,  35, 361, 621, 381, 280, 637,
#        619, 349,  22, 176, 331, 786, 242, 298, 290, 706, 152, 587, 800,
#        417, 608, 740, 890, 806, 255, 683, 253, 883, 114, 882, 497, 546,
#        839, 158, 856, 447, 240, 248, 553,  56, 711, 666, 702, 668, 733,
#        775,  97, 396, 595, 174, 687, 561,  44, 461, 594, 700, 103, 569,
#        596, 475,  87, 459,  69, 633, 107, 196, 793, 848, 780, 865, 732,
#        216,  33,  53,  28, 265, 264, 424, 344, 268, 770,  86, 777, 547,
#        712, 751, 109, 557,  19, 159, 548, 688, 797, 301, 584,  64, 307,
#        420,  99, 520,  15, 309,  43, 488, 485, 339, 810, 626, 276,  54,
#        342, 478, 314,  38, 304, 356, 835, 787, 748, 678, 632, 758, 681,
#        323, 888, 468, 432, 671,  79, 864, 181,   3, 456,  96, 476, 101,
#        819, 457, 504,  80,  91, 869, 373, 293, 693, 391, 799, 407, 610,
#        202, 843, 516, 353, 442, 665, 134, 258, 611, 222, 660, 807, 123,
# ...

# %%
#X_test

# %%
#X_train

# %%
#y_train

# %%
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier(n_neighbors=1)
knc.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=1)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
y_pred = knc.predict(X_test)
print(classification_report(y_test, y_pred))
roc_auc_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        94
#            1       0.77      0.81      0.79        86
#
#     accuracy                           0.79       180
#    macro avg       0.79      0.80      0.79       180
# weighted avg       0.80      0.79      0.79       180
# 0.7952746165264721

# %%
knc = KNeighborsClassifier(n_neighbors=2)
knc.fit(X_train, y_train)
y_pred = knc.predict(X_test)
print(classification_report(y_test, y_pred))
roc_auc_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79        94
#            1       0.80      0.70      0.75        86
#
#     accuracy                           0.77       180
#    macro avg       0.78      0.77      0.77       180
# weighted avg       0.78      0.77      0.77       180
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.7690499752597724

# %%
knc = KNeighborsClassifier(n_neighbors=3)
knc.fit(X_train, y_train)
y_pred = knc.predict(X_test)
print(classification_report(y_test, y_pred))
roc_auc_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80        94
#            1       0.76      0.87      0.81        86
#
#     accuracy                           0.81       180
#    macro avg       0.81      0.81      0.81       180
# weighted avg       0.81      0.81      0.81       180
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.8083869371598219

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=2)#max_depth=8
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)
print(classification_report(y_test, y_pred))
roc_auc_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        94
#            1       0.85      0.87      0.86        86
#
#     accuracy                           0.87       180
#    macro avg       0.87      0.87      0.87       180
# weighted avg       0.87      0.87      0.87       180
# 0.8668975754576942

# %%
prediction=pd.cut(y_pred,bins=[0,0.5,1],labels=['N','Y'])
ypred = (prediction == 'Y').astype(int)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()#max_features=0.45, n_estimators=85
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(classification_report(y_test, ypred))
roc_auc_score(y_test, ypred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        94
#            1       0.83      0.88      0.85        86
#
#     accuracy                           0.86       180
#    macro avg       0.86      0.86      0.86       180
# weighted avg       0.86      0.86      0.86       180
# 0.8567540821375557
